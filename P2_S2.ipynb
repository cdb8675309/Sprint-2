# %%
import pandas as pd
import numpy as np
red_wine = pd.read_csv('/Users/cd/Documents/Code Academy Berlin/Project 2/wine+quality/winequality-red.csv', sep = ';')
red_wine_copy = red_wine.copy()
white_wine = pd.read_csv('/Users/cd/Documents/Code Academy Berlin/Project 2/wine+quality/winequality-white.csv', sep = ';')
white_wine_copy = white_wine.copy()

# %%
def add_underscores(red_wine):
    red_wine.columns = red_wine.columns.str.replace(' ', '_')
    return red_wine

# %%
red_wine = add_underscores(red_wine)

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
red_wine['quality_label'] = red_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# %%
# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
red_wine['quality_label'] = pd.Categorical(red_wine['quality_label'],
categories=['low', 'medium', 'high'])

# %%
def add_underscores(white_wine):
    white_wine.columns = white_wine.columns.str.replace(' ', '_')
    return white_wine

# %%
white_wine = add_underscores(white_wine)

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
white_wine['quality_label'] = white_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# %%
# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
white_wine['quality_label'] = pd.Categorical(white_wine['quality_label'],
categories=['low', 'medium', 'high'])

# %%
#here i make a column titled red_or_white in the white_wine list, and give all the white wines property 'white'

white_wine['red_or_white'] = 'white'

white_wine
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
#here i make a column titled red_or_white in the red_wine list, and give all the red wines property 'red'


red_wine['red_or_white'] = 'red'

red_wine
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
combiwines = pd.concat([red_wine, white_wine], ignore_index=True)
combiwines
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
#here i create a combined data frame of the descriptions of red and white wines, and give them some keys for red wines stats and white wines stats

combined_wines_desc = pd.concat([red_wine.describe(), white_wine.describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
combined_wines_desc
# Out:
#       Red Wines Stats                                               \
#         fixed_acidity volatile_acidity  citric_acid residual_sugar
# count     1599.000000      1599.000000  1599.000000    1599.000000
# mean         8.319637         0.527821     0.270976       2.538806
# std          1.741096         0.179060     0.194801       1.409928
# min          4.600000         0.120000     0.000000       0.900000
# 25%          7.100000         0.390000     0.090000       1.900000
# 50%          7.900000         0.520000     0.260000       2.200000
# 75%          9.200000         0.640000     0.420000       2.600000
# max         15.900000         1.580000     1.000000      15.500000
#
#                                                                           \
#          chlorides free_sulfur_dioxide total_sulfur_dioxide      density
# count  1599.000000         1599.000000          1599.000000  1599.000000
# mean      0.087467           15.874922            46.467792     0.996747
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

red_wine.hist(bins=15, color='red', edgecolor='black', linewidth=1.0, xlabelsize=8, ylabelsize=8, grid=False)

plt.tight_layout(rect=(0, 0, 1.2, 1.2))

rt = plt.suptitle('Red Wine Univariate Plots', x=0.65, y=1.25, fontsize=15)

# %%
white_wine.hist(bins=15, color='grey', edgecolor='black', linewidth=1.0, xlabelsize=8, ylabelsize=8, grid=False)

plt.tight_layout(rect=(0, 0, 1.2, 1.2))

rt = plt.suptitle('White Wine Univariate Plots', x=0.65, y=1.25, fontsize=15)

# %%
#For example, take the feature named residual sugar and plot the distributions across data pertaining to red and white wine samples.
import numpy as np
import matplotlib.pyplot as plt

#fig, (ax1, ax2) = plt.subplots(1,2, sharey=True)
fig, axis = plt.subplots()
fig.suptitle('Residual Sugar Content in Wine')

red_wine('residual_sugar').hist(red_wine('residual_sugar'), red_wine.value_counts())
#ax2.hist(white_wine('residual_sugar'), white_wine.value_counts())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 9
#       6 fig, axis = plt.subplots()
#       7 fig.suptitle('Residual Sugar Content in Wine')
# ----> 9 red_wine('residual_sugar').hist(red_wine('residual_sugar'), red_wine.value_counts())
#      10 #ax2.hist(white_wine('residual_sugar'), white_wine.value_counts())
#      11 plt.show()
#
# TypeError: 'DataFrame' object is not callable

# %%
#For example, take the feature named residual sugar and plot the distributions across data pertaining to red and white wine samples. (via Seaborn)


import seaborn as sns

fig, ax = plt.subplots(1,2, figsize=(10,5))


sns.histplot(data=red_wine, x = 'residual_sugar', ax=ax[0], color='red', binwidth=1, ).set(title='Red Wine', ylabel = 'Frequency')
sns.histplot(data=white_wine, x = 'residual_sugar', ax=ax[1], color='white', bins=20).set(title='White Wine', ylabel = 'Frequency')
fig.suptitle('Residual Sugar Content in Wine')

ax[0].set_ylim(top=2500)
ax[1].set_ylim(top=2500)
plt.show()

# %%
#citric acid content, frequency, by wine type

import seaborn as sns

fig, ax = plt.subplots(1,2, sharex=True, figsize=(10,5))


sns.histplot(data=red_wine, x = 'citric_acid', ax=ax[0], color='red', bins=20 ).set(title='Red Wine', ylabel = 'Frequency')
sns.histplot(data=white_wine, x = 'citric_acid', ax=ax[1], color='white', bins=20).set(title='White Wine', ylabel = 'Frequency')
fig.suptitle('Citric Acid Content in Wine')

ax[0].set_ylim(top=2100)
ax[1].set_ylim(top=2100)
plt.show()

# %%
#chlorides content, frequency, by wine type

import seaborn as sns

fig, ax = plt.subplots(1,2, sharex=True, figsize=(10,5))

sns.histplot(data=red_wine, x = 'chlorides', ax=ax[0], color='red', bins=15 ).set(title='Red Wine', ylabel = 'Frequency')
sns.histplot(data=white_wine, x = 'chlorides', ax=ax[1], color='white', bins=15).set(title='White Wine', ylabel = 'Frequency')
fig.suptitle('Chlorides Content in Wine')

ax[0].set_ylim(top=3500)
ax[1].set_ylim(top=3500)
plt.show()

# %%
#volatile acidity content, frequency, by wine type

import seaborn as sns

fig, ax = plt.subplots(1,2, sharex=True, figsize=(10,5))


sns.histplot(data=red_wine, x = 'volatile_acidity', ax=ax[0], color='red', bins=20).set(title='Red Wine', ylabel = 'Frequency')
sns.histplot(data=white_wine, x = 'volatile_acidity', ax=ax[1], color='white', bins=20).set(title='White Wine', ylabel = 'Frequency')
fig.suptitle('Volatile Acidity in Wine')

ax[0].set_ylim(top=1300)
ax[1].set_ylim(top=1300)
ax[0].axvline(x=0.5, color='blue', alpha=0.75)
ax[1].axvline(x=0.50, color='blue', alpha=0.75)
plt.show()

# %%
combiwines.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality quality_label red_or_white
# ...

# %%
corr_combiwines = combiwines.corr()
corr_combiwines.head()
# Out:
# /var/folders/dt/36zskqd97kv75gn6l517twyh0000gn/T/ipykernel_33973/1077547348.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_combiwines = combiwines.corr()
#                   fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity          1.000000          0.219008     0.324436
# volatile_acidity       0.219008          1.000000    -0.377981
# citric_acid            0.324436         -0.377981     1.000000
# residual_sugar        -0.111981         -0.196011     0.142451
# chlorides              0.298195          0.377124     0.038998
#
#                   residual_sugar  chlorides  free_sulfur_dioxide  \
# fixed_acidity          -0.111981   0.298195            -0.282735
# volatile_acidity       -0.196011   0.377124            -0.352557
# ...

# %%
#working seaborn heatmap using .corr

sns.heatmap(corr_combiwines, annot=True, cmap="coolwarm_r")
sns.set(rc = {'figure.figsize':(15,8)})

# %%
#working seaborn heatmap using .corr

corr_whitewine = white_wine.corr()
sns.heatmap(corr_whitewine, annot=True, cmap="coolwarm_r")
# Out:
# /var/folders/dt/36zskqd97kv75gn6l517twyh0000gn/T/ipykernel_33973/2659247468.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_whitewine = white_wine.corr()
# <Axes: >

# %%
#working seaborn heatmap using .corr

corr_redwine = red_wine.corr()
sns.heatmap(corr_redwine, annot=True, cmap="seismic")
# Out:
# /var/folders/dt/36zskqd97kv75gn6l517twyh0000gn/T/ipykernel_33973/2158296197.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_redwine = red_wine.corr()
# <Axes: >

# %%
#incomplete jointplot, wip


sns.jointplot(data=red_wine, x='quality',y='sulphates', color='red', marginal_ticks=True,  height=5, ratio=2, space=0.5,
              marginal_kws= dict(bins=15, linewidth=0))
#sns.set_style('ticks')

plt.show()

# %%
g = sns.JointGrid(data=red_wine, x = 'quality', y = 'sulphates')
g.plot(sns.scatterplot, sns.histplot, color="red", )

# %%
#red wine jointplot seaborn
g = sns.JointGrid(marginal_ticks=True, ratio=3, space=2, height=8)
x, y = red_wine['quality'], red_wine['sulphates']
sns.scatterplot(x=x, y=y, ax=g.ax_joint, color='r', alpha=1)
sns.histplot(x=x, linewidth=0, ax=g.ax_marg_x, bins=10, color='r', alpha=1)
g.ax_marg_x.tick_params(labelbottom=True)
g.ax_marg_x.set_ylabel('')

sns.histplot(y=y, linewidth=0, ax=g.ax_marg_y, bins=15, color='r', alpha=1)
g.ax_marg_y.tick_params(labelleft=True)

g.ax_marg_y.set_xlabel('')
g.fig.suptitle('Red Wine Sulphates - Quality')
plt.tight_layout()
sns.despine(bottom = False, left = False, right=False, top=False)
plt.show()

# %%
#white wine jointplot seaborn
#red wine jointplot seaborn
g = sns.JointGrid(marginal_ticks=True, ratio=3, space=2, height=8)
x, y = white_wine['quality'], white_wine['sulphates']

sns.scatterplot(x=x, y=y, ax=g.ax_joint, color='grey', alpha=1)

sns.histplot(x=x, linewidth=0, ax=g.ax_marg_x, bins=10, color='grey', alpha=1)
g.ax_marg_x.tick_params(labelbottom=True)
g.ax_marg_x.set_ylabel('')

sns.histplot(y=y, linewidth=0, ax=g.ax_marg_y, bins=15, color='grey', alpha=1)
g.ax_marg_y.tick_params(labelleft=True)

g.ax_marg_y.set_xlabel('')

sns.despine(bottom = False, left = False, right=False, top=False)


g.fig.suptitle('White Wine Sulphates - Quality')
plt.tight_layout()

plt.show()

# %%
red_wine.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality quality_label red_or_white
# ...

# %%
#scatterplot of redwine, sulphates, alcohol
#use s= to set scatterplot dot size
plt.figure(figsize=(8,6))
sns.scatterplot(data=red_wine, x='alcohol', y='sulphates', hue='quality_label', palette='hls', alpha=0.5, s=75 )
plt.suptitle('Red Wines - Sulphates, Alcohol, and Quality')
plt.show()

# %%
for i in red_wine.columns[0:10]:
    fig, ax =plt.subplots()
    sns.scatterplot(data=red_wine, x='alcohol', y=i, hue='quality_label', palette='hls', size='quality_label', sizes={"low": 20, "medium": 70, "high": 200}, alpha=0.5, s=75)
    plt.suptitle('Red Wines: y-factor, Alcohol, and Quality')
    plt.show()
